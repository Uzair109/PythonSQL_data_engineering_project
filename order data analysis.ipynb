# %%
import kaggle 
# !pip install kaggle
# !kaggle datasets download ankitbansal06/retail-orders -f orders.csv
# Out:
# Dataset URL: https://www.kaggle.com/datasets/ankitbansal06/retail-orders
# License(s): CC0-1.0
# orders.csv.zip: Skipping, found more recently modified local copy (use --force to force download)

# %%
import zipfile
zip_ref = zipfile.ZipFile('C:\\Users\\User\\data e\\orders.csv.zip')
zip_ref.extractall()
zip_ref.close()

# %%
import pandas as pd
df = pd.read_csv('C:\\Users\\User\\data e\\orders.csv',na_values=['Not Available','unknown'])
df['Ship Mode'].unique()
# Out:
# array(['Second Class', 'Standard Class', nan, 'First Class', 'Same Day'],
#       dtype=object)

# %%
df.columns = df.columns.str.lower()
df.columns = df.columns.str.replace(' ','_')
df.head()
# Out:
#    order_id  order_date       ship_mode    segment        country  \
# 0         1  2023-03-01    Second Class   Consumer  United States
# 1         2  2023-08-15    Second Class   Consumer  United States
# 2         3  2023-01-10    Second Class  Corporate  United States
# 3         4  2022-06-18  Standard Class   Consumer  United States
# 4         5  2022-07-13  Standard Class   Consumer  United States
#
#               city       state  postal_code region         category  \
# 0        Henderson    Kentucky        42420  South        Furniture
# 1        Henderson    Kentucky        42420  South        Furniture
# 2      Los Angeles  California        90036   West  Office Supplies
# 3  Fort Lauderdale     Florida        33311  South        Furniture
# 4  Fort Lauderdale     Florida        33311  South  Office Supplies
#
#   sub_category       product_id  cost_price  list_price  quantity  \
# 0    Bookcases  FUR-BO-10001798         240         260         2
# ...

# %%
df['discount'] = df['list_price']*df['discount_percent']*.01
df['sale_price'] = df['list_price']-df['discount']
df['profit'] = df['sale_price']-df['cost_price']
df
# Out:
#       order_id  order_date       ship_mode    segment        country  \
# 0            1  2023-03-01    Second Class   Consumer  United States
# 1            2  2023-08-15    Second Class   Consumer  United States
# 2            3  2023-01-10    Second Class  Corporate  United States
# 3            4  2022-06-18  Standard Class   Consumer  United States
# 4            5  2022-07-13  Standard Class   Consumer  United States
# ...        ...         ...             ...        ...            ...
# 9989      9990  2023-02-18    Second Class   Consumer  United States
# 9990      9991  2023-03-17  Standard Class   Consumer  United States
# 9991      9992  2022-08-07  Standard Class   Consumer  United States
# 9992      9993  2022-11-19  Standard Class   Consumer  United States
# 9993      9994  2022-07-17    Second Class   Consumer  United States
#
#                  city       state  postal_code region         category  \
# ...

# %%
df['order_date'] = pd.to_datetime(df['order_date'],format="%Y-%m-%d") 
df
# Out:
#       order_id order_date       ship_mode    segment        country  \
# 0            1 2023-03-01    Second Class   Consumer  United States
# 1            2 2023-08-15    Second Class   Consumer  United States
# 2            3 2023-01-10    Second Class  Corporate  United States
# 3            4 2022-06-18  Standard Class   Consumer  United States
# 4            5 2022-07-13  Standard Class   Consumer  United States
# ...        ...        ...             ...        ...            ...
# 9989      9990 2023-02-18    Second Class   Consumer  United States
# 9990      9991 2023-03-17  Standard Class   Consumer  United States
# 9991      9992 2022-08-07  Standard Class   Consumer  United States
# 9992      9993 2022-11-19  Standard Class   Consumer  United States
# 9993      9994 2022-07-17    Second Class   Consumer  United States
#
#                  city       state  postal_code region         category  \
# 0           Henderson    Kentucky        42420  South        Furniture
# ...

# %%
df.drop(columns=['list_price','cost_price','discount_percent'],inplace = True)
df
# Out:
#       order_id order_date       ship_mode    segment        country  \
# 0            1 2023-03-01    Second Class   Consumer  United States
# 1            2 2023-08-15    Second Class   Consumer  United States
# 2            3 2023-01-10    Second Class  Corporate  United States
# 3            4 2022-06-18  Standard Class   Consumer  United States
# 4            5 2022-07-13  Standard Class   Consumer  United States
# ...        ...        ...             ...        ...            ...
# 9989      9990 2023-02-18    Second Class   Consumer  United States
# 9990      9991 2023-03-17  Standard Class   Consumer  United States
# 9991      9992 2022-08-07  Standard Class   Consumer  United States
# 9992      9993 2022-11-19  Standard Class   Consumer  United States
# 9993      9994 2022-07-17    Second Class   Consumer  United States
#
#                  city       state  postal_code region         category  \
# 0           Henderson    Kentucky        42420  South        Furniture
# ...

# %%
import sqlalchemy as sql
# import pymysql
# !pip install pymysql
engine = sql.create_engine('mysql+pymysql://root:MyNewPass@localhost:3306/sales')
conn = engine.connect()

# %%
df.to_sql('df_orders', con=conn, index = False, if_exists = 'append')
# Out:
# 9994

# %%
df.columns

# %%
#for visualization

import matplotlib.pyplot as plt
import seaborn as sns

# %%
#bar plot find top 10 highest revenue generating products
plt.figure(figsize=(8, 4))
sns.barplot(x='revenue', y='sub_category', data=top_products, palette='viridis')
plt.xlabel('Revenue')
plt.ylabel('Products')
plt.title('Top 10 Products by Revenue')
plt.show()
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_3012\3995853608.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='revenue', y='sub_category', data=top_products, palette='viridis')

# %%
#barplot find top 5 highest selling products in each region
sns.set(style='whitegrid')
plt.figure(figsize=(10, 5))
sns.barplot(x='sub_category', y='revenue', hue='region', data=top_products, palette='viridis')
plt.xlabel('Product')
plt.ylabel('Revenue')
plt.title('Top 5 Highest Selling Products by Revenue in Each Region')
plt.legend(title='Region', bbox_to_anchor=(1.05, 1), loc='upper left')
plt.tight_layout()

# %%
#barplot find month over month growth comparison for 2022 and 2023 sales
plt.figure(figsize=(10, 5))
sns.barplot(data=pivot_table.melt(id_vars='odr_month', value_vars=['sales_of_2022', 'sales_of_2023']), x='odr_month', y='value', hue='variable', palette='viridis')
plt.xlabel('Month')
plt.ylabel('Sales Revenue')
plt.title('Monthly Sales Comparison: 2022 vs 2023')
plt.legend(title='Year',  bbox_to_anchor=(1.05, 1), loc='upper left')
plt.tight_layout()

# %%
#for each category which month had highest sales
plt.figure(figsize=(10, 5))
sns.barplot(data=top_revenue_products, x='combined_label', y='revenue', hue='category', palette='viridis')
plt.xlabel('Category & Month')
plt.ylabel('Revenue')
plt.title('Top Revenue Generating Products by Category Each Month')
plt.legend(title='Category',bbox_to_anchor=(1.05, 1), loc='upper left')
plt.tight_layout()

# %%
#bar plot for sales comparison
plt.figure(figsize=(8, 4))
x = range(len(top_growth_subcategories))
plt.bar(x, top_growth_subcategories['sales_of_2022'], width=bar_width, label='Sales 2022', color='blue', alpha=0.7)
plt.bar([p + bar_width for p in x], top_growth_subcategories['sales_of_2023'], width=bar_width, label='Sales 2023', color='orange', alpha=0.7)
plt.xlabel('Sales')
plt.ylabel('Sales')
plt.title('Product Sales Comparison 2022 vs 2023')
plt.legend(title='Year',bbox_to_anchor=(1.05, 1), loc='upper left')
plt.tight_layout()
